# %%
f = open("data1.txt", "r", encoding="utf-8")
read = f.read()
f.close()

print(read)
# Out:
# Life is too short.
# So, you need Python.
# Python is easy,
# and useful on many fields.

# %%
read
# Out:
# 'Life is too short.\nSo, you need Python.\nPython is easy,\nand useful on many fields.'

# %%
with open("data1.txt", "r", encoding="utf-8") as f:
    f = f.read()
print(f)
# Out:
# Life is too short.
# So, you need Python.
# Python is easy,
# and useful on many fields.

# %%
f
# Out:
# 'Life is too short.\nSo, you need Python.\nPython is easy,\nand useful on many fields.'
